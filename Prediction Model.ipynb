# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.plotly as py
import plotly.graph_objs as go

# Machine Learning 
from sklearn.linear_model import LogisticRegression 
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron 
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics 
from sklearn.cross_validation import KFold
# Out:
# /anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning:
#
# This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.

# %%
path = './df.xlsx'

# %%
df = pd.read_excel(path)
df.head()
# Out:
#          Country  Type  Amateur Built  Number of Engines  Injury Severity  \
# 0  United States     1            1.0                  1                0
# 1  United States     1            0.0                  1                0
# 2  United States     1            1.0                  1                0
# 3  United States     1            0.0                  1                0
# 4  United States     1            0.0                  1                0
#
#    Report_Factual  Report_Foreign  Report_Preliminary  Report_Probable Cause  \
# 0               0               0                   1                      0
# 1               0               0                   1                      0
# 2               0               0                   1                      0
# 3               0               0                   1                      0
# 4               0               0                   1                      0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81366 entries, 0 to 81365
# Data columns (total 47 columns):
# Country                                80859 non-null object
# Type                                   81366 non-null int64
# Amateur Built                          80749 non-null float64
# Number of Engines                      81366 non-null int64
# Injury Severity                        81366 non-null int64
# Report_Factual                         81366 non-null int64
# Report_Foreign                         81366 non-null int64
# Report_Preliminary                     81366 non-null int64
# Report_Probable Cause                  81366 non-null int64
# Purpose_Aerial Application             81366 non-null int64
# Purpose_Aerial Observation             81366 non-null int64
# Purpose_Air Drop                       81366 non-null int64
# Purpose_Air Race/Show                  81366 non-null int64
# Purpose_Banner Tow                     81366 non-null int64
# ...

# %%
# To check if there are any missing values in the dataframe and fill the missing data with the median value
df.isnull().any()
df = df.fillna(df.median())

# %%
#df.isnull().any()

# %%
df_training = df[:70000]
df_testing = df[70000:]

# %%
df_testing = df_testing.drop(['Injury Severity','Country'],axis = 1)
X_train = df_training.drop(['Injury Severity','Country'],axis = 1)
Y_train = df_training['Injury Severity']
X_test = df_testing.copy()

# %%
X_train.shape, Y_train.shape, X_test.shape
# Out:
# ((70000, 45), (70000,), (11366, 45))

# %% [markdown]
# ## Predictions

# %%
## Logistic Regression 

logreg = LogisticRegression()
logreg.fit(X_train, Y_train)
Y_pred = logreg.predict(X_test)
acc_log = round(logreg.score(X_train, Y_train) * 100, 2)
acc_log
# Out:
# 88.08

# %%
# # Support Vector Machine 

# svc = SVC()
# svc.fit(X_train, Y_train)
# Y_pred1 = svc.predict(X_test)
# acc_svc = round(svc.score(X_train, Y_train) * 100, 2)
# acc_svc

# %%
# # Decision Tree

# decision_tree = DecisionTreeClassifier()
# decision_tree.fit(X_train, Y_train)
# Y_pred2 = decision_tree.predict(X_test)
# acc_decision_tree = round(decision_tree.score(X_train, Y_train) * 100, 2)
# acc_decision_tree

# %%
# # KNN 

# knn = KNeighborsClassifier(n_neighbors = 3)
# knn.fit(X_train, Y_train)
# Y_pred2 = knn.predict(X_test)
# acc_knn = round(knn.score(X_train, Y_train) * 100, 2)
# acc_knn

# %%
prediction = pd.DataFrame({
    'Injury Severity' : Y_pred
})

# %%
prediction.head()
# Out:
#    Injury Severity
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
injuries = {0: 'Non-Fatal', 1:'Fatal'}
prediction.replace(injuries, inplace=True)
prediction
# Out:
#       Injury Severity
# 0           Non-Fatal
# 1           Non-Fatal
# 2           Non-Fatal
# 3           Non-Fatal
# 4           Non-Fatal
# 5               Fatal
# 6           Non-Fatal
# 7               Fatal
# 8           Non-Fatal
# 9           Non-Fatal
# 10              Fatal
# 11          Non-Fatal
# 12          Non-Fatal
# 13          Non-Fatal
# 14          Non-Fatal
# 15          Non-Fatal
# 16          Non-Fatal
# 17          Non-Fatal
# 18          Non-Fatal
# 19              Fatal
# 20              Fatal
# 21              Fatal
# 22          Non-Fatal
# 23              Fatal
# 24              Fatal
# 25          Non-Fatal
# 26              Fatal
# 27          Non-Fatal
# 28          Non-Fatal
# 29          Non-Fatal
# ...               ...
# 11336       Non-Fatal
# 11337           Fatal
# 11338       Non-Fatal
# 11339       Non-Fatal
# 11340       Non-Fatal
# 11341           Fatal
# 11342           Fatal
# 11343       Non-Fatal
# 11344       Non-Fatal
# ...

# %%
df_testing.to_excel('./Testing Data.xlsx', index=False)
df_training.to_excel('./Training Data.xlsx', index=False)
prediction.to_excel('./Results.xlsx', index=False)
